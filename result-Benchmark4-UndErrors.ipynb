# %% [markdown]
# ### - import ebeam file, static seed laser.

# %%
from functions import GenesisOut
import matplotlib.pyplot as plt
#filepath = './benchmark/Benchmark1-SASE/Benchmark.out.h5'
filepath = './benchmark/Benchmark4-UndErrors/Benchmark.out.h5'
out = GenesisOut.GenesisOut(filepath)
# Out:
# Benchmark.out.h5 loaded
# <table>
# <tbody>
# <tr><td>group  </td><td>parameter                                                                                                                                                                                                                                                                                   </td></tr>
# <tr><td>Beam   </td><td>[&#x27;alphax&#x27;, &#x27;alphay&#x27;, &#x27;betax&#x27;, &#x27;betay&#x27;, &#x27;bunching&#x27;, &#x27;bunching2&#x27;, &#x27;bunching3&#x27;, &#x27;bunchingphase&#x27;, &#x27;bunchingphase2&#x27;, &#x27;bunchingphase3&#x27;, &#x27;current&#x27;, &#x27;efield&#x27;, &#x27;emitx&#x27;, &#x27;emity&#x27;, &#x27;energy&#x27;, &#x27;energyspread&#x27;, &#x27;npart_in_slice&#x27;, &#x27;pxposition&#x27;, &#x27;pyposition&#x27;, &#x27;xposition&#x27;, &#x27;xsize&#x27;, &#x27;yposition&#x27;, &#x27;ysize&#x27;]</td></tr>
# ...

# %%
out.show_info('Beam')
# Out:
# Beam
# alphax : -0.7241377808208709
# alphay : 1.3626284719356665
# betax : 8.820880411456864
# betay : 16.903898645239
# bunching : size (1105, 1)
# bunching2 : size (1105, 1)
# bunching3 : size (1105, 1)
# bunchingphase : size (1105, 1)
# bunchingphase2 : size (1105, 1)
# bunchingphase3 : size (1105, 1)
# current : 3000.0
# efield : size (1105, 1)
# emitx : 4.0000010618279754e-07
# emity : 3.9999985141130456e-07
# energy : size (1105, 1)
# energyspread : size (1105, 1)
# npart_in_slice : size (1105, 1)
# pxposition : size (1105, 1)
# pyposition : size (1105, 1)
# xposition : size (1105, 1)
# xsize : size (1105, 1)
# yposition : size (1105, 1)
# ysize : size (1105, 1)

# %%
out.show_info('Field')
# Out:
# Field
# dgrid : 1.5748031496062992e-06
# intensity-farfield : size (1105, 1)
# intensity-nearfield : size (1105, 1)
# ngrid : 255
# phase-farfield : size (1105, 1)
# phase-nearfield : size (1105, 1)
# power : size (1105, 1)
# xposition : size (1105, 1)
# xsize : size (1105, 1)
# yposition : size (1105, 1)
# ysize : size (1105, 1)

# %%
plt.plot(out.zplot, out('Field', 'xsize'), label='x')
plt.plot(out.zplot, out('Field', 'ysize'), label='y')
plt.legend()
plt.xlabel('z [m]')
plt.ylabel('field size')
# Out:
# Text(0, 0.5, 'field size')

# %%
plt.plot(out.zplot, out('Beam', 'xsize'), label='x')
plt.plot(out.zplot, out('Beam', 'ysize'), label='y')
plt.legend()
plt.xlabel('z [m]')
plt.ylabel('beam size')
# Out:
# Text(0, 0.5, 'beam size')

# %%
plt.plot(out.zplot, out('intensity-farfield'), label='far field')
plt.plot(out.zplot, out('intensity-nearfield'), label='near field')
plt.xlabel('z [m]')
plt.ylabel('intensity')
plt.show()

# %%
plt.plot(out.zplot, out('Field', 'power'))
plt.xlabel('z [m]')
plt.ylabel(' P [W]')
plt.title('power')
plt.show()
